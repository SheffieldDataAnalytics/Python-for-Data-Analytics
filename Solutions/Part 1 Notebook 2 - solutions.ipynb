# %% [markdown]
# <b><font size ="6">Notebook 2 - solutions</font></b>
#
# The following notebook contains the solutions for the second notebook in the tutorial. It is recommended that you check those solutions either after you finish the whole notebook.

# %%
# Cashpoint function - first definition

def cashpoint(truepin,balance):
    pinAttempt = int(input('Please enter your PIN: '))
    if pinAttempt == truepin:
        print ("\nPlease choose your transaction type")
        print ("   - to request a balance  - enter 1")
        print ("   - to make a withdrawal  - enter 2")
        print ("   - to top-up a telephone - enter 3")
        transactionType = float(input('\nEnter your choice: '))
        if (transactionType == 1):
            print ("Your balance is", balance, 'GBP')
            print ("Thank you for using this service.")
        elif transactionType == 2:
            amount = float(input('Please enter your withdrawal amount: '))
            print ("Please take your cash.")
            print ("Your new balance is", balance - amount, 'GBP')
        elif transactionType == 3:
            print ("\nSorry: the top-up service is not currently available")
        else:
            print ("Error: transaction type not recognised.")
    else:
        print ("\nError: PIN authorisation failed - exiting.")

# Test calls for the cashpoint function        
print ('TEST-EXAMPLE 1')
result = cashpoint(1234,3415.55)
print ('---------\nRESULT:', result)
print ('-' * 50, '\n')

print ('TEST-EXAMPLE 2')
result = cashpoint(2345,2200.00)
print ('---------\nRESULT:', result)
print ('-' * 50, '\n')

print ('TEST-EXAMPLE 3')
result = cashpoint(3456,175.55)
print ('---------\nRESULT:', result)
print ('-' * 50, '\n')

# %%
# Cashpoint function - second definition
# Replaces some of the print statements with return statements

def cashpoint(truepin,balance):
    pinAttempt = int(input('Please enter your PIN: '))
    if pinAttempt == truepin:
        print ("\nPlease choose your transaction type")
        print ("   - to request a balance  - enter 1")
        print ("   - to make a withdrawal  - enter 2")
        print ("   - to top-up a telephone - enter 3")
        transactionType = int(input('\nEnter your choice: '))
        if (transactionType == 1):
            print ("Your balance is", balance, 'GBP')
            print ("Thank you for using this service.")
            return ("balance-request")
        elif transactionType == 2:
            amount = int(input('Please enter your withdrawal amount: '))
            print ("Please take your cash.")
            print ("Your new balance is", balance - amount, 'GBP')
            return ("withdrawal-request",amount)
        elif transactionType == 3:
            print ("\nSorry: the top-up service is not currently available")
            return ("mobile-topup",0)
        else:
            print ("Error: transaction type not recognised.")
            return ("transaction-error")
    else:
        print ("\nError: PIN authorisation failed - exiting.")
        return ("PIN-error")

# Test calls for the cashpoint function        
print ('TEST-EXAMPLE 1')
result = cashpoint(1234,3415.55)
print ('---------\nRESULT:', result)
print ('-' * 50, '\n')

print ('TEST-EXAMPLE 2')
result = cashpoint(2345,2200.00)
print ('---------\nRESULT:', result)
print ('-' * 50, '\n')

print ('TEST-EXAMPLE 3')
result = cashpoint(3456,175.55)
print ('---------\nRESULT:', result)
print ('-' * 50, '\n')

# %%
# Cashpoint function - third definition
# Main function broken down. Uses calls to other function to perform the task

def cashpoint(truepin,balance):
    if checkPIN(truepin):
        print ("\nPlease choose your transaction type")
        print ("   - to request a balance  - enter 1")
        print ("   - to make a withdrawal  - enter 2")
        print ("   - to top-up a telephone - enter 3")
        transactionType = int(input('\nEnter your choice: '))
        if (transactionType == 1):
            print ("Your balance is", balance, 'GBP')
            print ("Thank you for using this service.")
            return ("balance-request")
        elif transactionType == 2:
            return withdrawal(balance)
        elif transactionType == 3:
            return mobileTopUp(balance)
        else:
            print ("Error: transaction type not recognised.")
            return ("transaction-error")
    else:
        print ("\nError: PIN authorisation failed - exiting.")
        return ("PIN-error")

# Checks once to see if entered pin is correct
def checkPIN_once(truepin):
    attempt = int(input('Please enter your PIN: '))
    if attempt == truepin:
        return (True)
    else:
        print ("PIN incorrect")
        return (False)

# Three attempts to check the pin, before closing the session
# Uses calls to checkPIN_once
def checkPIN(truepin):
    if checkPIN_once(truepin):
        return (True)
    print ("\nPlease try again (2nd attempt).")
    if checkPIN_once(truepin):
        return (True)
    print ("\nPlease try again (final attempt).")
    if checkPIN_once(truepin):
        return (True)
    return (False)

# Withdrawal function
def withdrawal(balance):
    maxWithdrawalAmount = 100.00
    print ("Withdrawal amount must be a multiple of 10 pounds.")
    amount = int(input('Please enter your withdrawal amount: '))
    if amount > maxWithdrawalAmount:
        print ("Amount exceeds maximum permitted withdrawal amount")
        print ("Request refused")
        return ("withdrawal-request:refused")
    elif amount > balance:
        print ("Amount exceeds available funds")
        print ("Request refused")
        return ("withdrawal-request:refused")
    elif multipleOfTen(amount):
        print ("Please take your cash.")
        print ("Your new balance is", balance - amount, 'GBP')
        return ("withdrawal-request",amount)
    else:
        print ("Amount is not a multiple of 10")
        print ("Request refused")
        return ("withdrawal-request:refused")

# Function to return only £10 bills to the user    
def multipleOfTen(amount):
    return (amount == int(amount / 10.0) * 10)

# Function to top-up mobile with credit
def mobileTopUp(balance):
    maxTopUp = 100.00
    print ("Please enter the number of the mobile phone you wish to top-up: ",)
    number1 = int(input())
    print ("Please RE-enter the number of the phone: ",)
    number2 = int(input())
    if number1 == number2:
        print ("Top-up amount must be a multiple of 10 pounds.")
        amount = int(input('Please enter your top-up amount: '))
        if amount > maxTopUp:
            print ("Amount exceeds maximum permitted top-up")
            print ("Request refused")
            return ("top-up-request:refused")
        elif amount > balance:
            print ("Amount exceeds available funds")
            print ("Request refused")
            return ("top-up-request:refused")
        elif multipleOfTen(amount):
            print ("Transaction authorised.")
            print ("Your new account balance is", balance - amount, 'GBP')
            return ("top-up-request",amount)
        else:
            print ("Amount is not a multiple of 10")
            print ("Request refused")
            return ("top-up-request:refused")
    else:
        print ("Error: the two numbers entered are different.")
        print ("Transaction cancelled.")
        return ("top-up-request:refused")
    
# Test calls for the cashpoint function        
print ('TEST-EXAMPLE 1')
result = cashpoint(1234,3415.55)
print ('---------\nRESULT:', result)
print ('-' * 50, '\n')

print ('TEST-EXAMPLE 2')
result = cashpoint(2345,2200.00)
print ('---------\nRESULT:', result)
print ('-' * 50, '\n')

print ('TEST-EXAMPLE 3')
result = cashpoint(3456,75.55)
print ('---------\nRESULT:', result)
print ('-' * 50, '\n')
